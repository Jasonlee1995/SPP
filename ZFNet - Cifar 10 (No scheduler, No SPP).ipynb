# %% [markdown]
# # ZFNet without SPP
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ## 1.1. Install matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.8/site-packages (3.4.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (8.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.19.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %% [markdown]
# ## 1.2. Import

# %%
import train

import torch
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
batch_size = 128

# %%
train_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop(256), transforms.RandomCrop(224), transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop(256), transforms.TenCrop(224),
    transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
    transforms.Lambda(lambda crops: torch.stack([transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], 
                                                                       std=[0.1950, 0.1922, 0.1940])(crop) for crop in crops]))
    ])

train_dataset = torchvision.datasets.CIFAR10('../../../../data/OCR/Jason/cifar10/', train=True, download=False, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)

test_dataset = torchvision.datasets.CIFAR10('../../../../data/OCR/Jason/cifar10/', train=False, download=False, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)

# %% [markdown]
# # 3. Train Model

# %%
pyramids = [6]
num_classes = 10

gpu_id = 7
print_freq = 130
epoch_print = 20

save = False
epochs = 261

lr = 0.01
momentum = 0.9
weight_decay = 0.0005

# %%
ZFNet = train.ZFNet_SPP(pyramids=pyramids, num_classes=num_classes, gpu_id=gpu_id, print_freq=print_freq, epoch_print=epoch_print)

# %%
ZFNet.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 2.3026, Test Loss : 2.3026, Train Acc : 4.6875, Test Acc : 10.0000
# Iteration : 260 - Train Loss : 2.3027, Test Loss : 2.3026, Train Acc : 4.6875, Test Acc : 10.0000
# Iteration : 390 - Train Loss : 2.3025, Test Loss : 2.3026, Train Acc : 11.7188, Test Acc : 10.0000
# Epoch 21 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.8990, Test Loss : 1.9114, Train Acc : 55.4688, Test Acc : 57.1900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 260 - Train Loss : 1.9142, Test Loss : 1.9040, Train Acc : 53.1250, Test Acc : 57.3600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 390 - Train Loss : 1.8884, Test Loss : 1.9092, Train Acc : 55.4688, Test Acc : 57.6800
# Epoch 41 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.7493, Test Loss : 1.7107, Train Acc : 70.3125, Test Acc : 78.0100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 260 - Train Loss : 1.6429, Test Loss : 1.7021, Train Acc : 82.0312, Test Acc : 78.8100
# Iteration : 390 - Train Loss : 1.7045, Test Loss : 1.7060, Train Acc : 77.3438, Test Acc : 78.7000
# Epoch 61 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5673, Test Loss : 1.6533, Train Acc : 89.0625, Test Acc : 83.6900
# Iteration : 260 - Train Loss : 1.6016, Test Loss : 1.6650, Train Acc : 86.7188, Test Acc : 82.3900
# Iteration : 390 - Train Loss : 1.5925, Test Loss : 1.6567, Train Acc : 87.5000, Test Acc : 83.4200
# Epoch 81 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5895, Test Loss : 1.6376, Train Acc : 86.7188, Test Acc : 85.3700
# Iteration : 260 - Train Loss : 1.5508, Test Loss : 1.6384, Train Acc : 91.4062, Test Acc : 85.1800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 390 - Train Loss : 1.5616, Test Loss : 1.6322, Train Acc : 91.4062, Test Acc : 86.0100
# Epoch 101 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5493, Test Loss : 1.6270, Train Acc : 91.4062, Test Acc : 86.8700
# Iteration : 260 - Train Loss : 1.5652, Test Loss : 1.6262, Train Acc : 91.4062, Test Acc : 86.4500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 390 - Train Loss : 1.5513, Test Loss : 1.6273, Train Acc : 91.4062, Test Acc : 86.8900
# Epoch 121 Started...
# Iteration : 130 - Train Loss : 1.5351, Test Loss : 1.6247, Train Acc : 92.9688, Test Acc : 86.4900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 260 - Train Loss : 1.5100, Test Loss : 1.6225, Train Acc : 96.0938, Test Acc : 87.0100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 390 - Train Loss : 1.5251, Test Loss : 1.6178, Train Acc : 92.9688, Test Acc : 87.5500
# Epoch 141 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5329, Test Loss : 1.6192, Train Acc : 92.1875, Test Acc : 87.7400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 260 - Train Loss : 1.5137, Test Loss : 1.6129, Train Acc : 95.3125, Test Acc : 88.0200
# Iteration : 390 - Train Loss : 1.5039, Test Loss : 1.6237, Train Acc : 97.6562, Test Acc : 86.9600
# Epoch 161 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5019, Test Loss : 1.6136, Train Acc : 96.0938, Test Acc : 88.0900
# Iteration : 260 - Train Loss : 1.5437, Test Loss : 1.6201, Train Acc : 92.1875, Test Acc : 87.1800
# Iteration : 390 - Train Loss : 1.4800, Test Loss : 1.6178, Train Acc : 98.4375, Test Acc : 87.5300
# Epoch 181 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5299, Test Loss : 1.6133, Train Acc : 92.9688, Test Acc : 88.3900
# Iteration : 260 - Train Loss : 1.5177, Test Loss : 1.6135, Train Acc : 94.5312, Test Acc : 88.2700
# Iteration : 390 - Train Loss : 1.4746, Test Loss : 1.6174, Train Acc : 99.2188, Test Acc : 87.7000
# Epoch 201 Started...
# Iteration : 130 - Train Loss : 1.5010, Test Loss : 1.6151, Train Acc : 96.8750, Test Acc : 87.8600
# Iteration : 260 - Train Loss : 1.5048, Test Loss : 1.6148, Train Acc : 96.0938, Test Acc : 87.8000
# Iteration : 390 - Train Loss : 1.5150, Test Loss : 1.6130, Train Acc : 96.0938, Test Acc : 88.2500
# Epoch 221 Started...
# Iteration : 130 - Train Loss : 1.5045, Test Loss : 1.6149, Train Acc : 94.5312, Test Acc : 87.7200
# Iteration : 260 - Train Loss : 1.4864, Test Loss : 1.6126, Train Acc : 97.6562, Test Acc : 88.2500
# Iteration : 390 - Train Loss : 1.5018, Test Loss : 1.6186, Train Acc : 96.8750, Test Acc : 87.5800
# Epoch 241 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.4959, Test Loss : 1.6097, Train Acc : 97.6562, Test Acc : 88.4500
# Iteration : 260 - Train Loss : 1.5103, Test Loss : 1.6140, Train Acc : 95.3125, Test Acc : 87.7700
# Iteration : 390 - Train Loss : 1.5160, Test Loss : 1.6142, Train Acc : 94.5312, Test Acc : 88.1500
# Epoch 261 Started...
# Iteration : 130 - Train Loss : 1.4946, Test Loss : 1.6187, Train Acc : 96.8750, Test Acc : 87.7900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 260 - Train Loss : 1.5111, Test Loss : 1.6102, Train Acc : 95.3125, Test Acc : 88.5600
# Iteration : 390 - Train Loss : 1.5288, Test Loss : 1.6110, Train Acc : 94.5312, Test Acc : 88.3900

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(ZFNet.train_losses, label='Train')
test_lossline, = plt.plot(ZFNet.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(ZFNet.train_acc, label='Train')
test_accline, = plt.plot(ZFNet.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
