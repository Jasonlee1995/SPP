# %% [markdown]
# # ZFNet with SPP
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ## 1.1. Install matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.8/site-packages (3.4.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (8.1.2)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.19.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %% [markdown]
# ## 1.2. Import

# %%
import train

import torch
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
batch_size = 128

# %%
train_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop(256), transforms.RandomCrop(224), transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop(256), transforms.TenCrop(224),
    transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
    transforms.Lambda(lambda crops: torch.stack([transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], 
                                                                       std=[0.1950, 0.1922, 0.1940])(crop) for crop in crops]))
    ])

train_dataset = torchvision.datasets.CIFAR10('../../../../data/OCR/Jason/cifar10/', train=True, download=False, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)

test_dataset = torchvision.datasets.CIFAR10('../../../../data/OCR/Jason/cifar10/', train=False, download=False, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)

# %% [markdown]
# # 3. Train Model

# %%
pyramids = [4, 3, 2, 1]
num_classes = 10

gpu_id = 5
print_freq = 130
epoch_print = 20

save = False
epochs = 261

lr = 0.01
momentum = 0.9
weight_decay = 0.0005

# %%
ZFNet = train.ZFNet_SPP(pyramids=pyramids, num_classes=num_classes, gpu_id=gpu_id, print_freq=print_freq, epoch_print=epoch_print)

# %%
ZFNet.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 2.3024, Test Loss : 2.3026, Train Acc : 9.3750, Test Acc : 10.0000
# Iteration : 260 - Train Loss : 2.3026, Test Loss : 2.3026, Train Acc : 7.8125, Test Acc : 10.0000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 390 - Train Loss : 2.3026, Test Loss : 2.3026, Train Acc : 14.0625, Test Acc : 10.0700
# Epoch 21 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.8828, Test Loss : 1.9258, Train Acc : 58.5938, Test Acc : 54.4300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 260 - Train Loss : 1.9562, Test Loss : 1.9034, Train Acc : 49.2188, Test Acc : 57.4100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 390 - Train Loss : 1.8838, Test Loss : 1.8883, Train Acc : 57.8125, Test Acc : 59.8500
# Epoch 41 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.6441, Test Loss : 1.7062, Train Acc : 82.0312, Test Acc : 77.4300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 260 - Train Loss : 1.7196, Test Loss : 1.6937, Train Acc : 73.4375, Test Acc : 79.2700
# Iteration : 390 - Train Loss : 1.7191, Test Loss : 1.7054, Train Acc : 73.4375, Test Acc : 77.8900
# Epoch 61 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5824, Test Loss : 1.6414, Train Acc : 87.5000, Test Acc : 84.2100
# Iteration : 260 - Train Loss : 1.6763, Test Loss : 1.6450, Train Acc : 78.9062, Test Acc : 84.1600
# Iteration : 390 - Train Loss : 1.6261, Test Loss : 1.6406, Train Acc : 83.5938, Test Acc : 84.1800
# Epoch 81 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.6006, Test Loss : 1.6191, Train Acc : 86.7188, Test Acc : 86.4100
# Iteration : 260 - Train Loss : 1.5633, Test Loss : 1.6199, Train Acc : 90.6250, Test Acc : 86.4100
# Iteration : 390 - Train Loss : 1.5979, Test Loss : 1.6267, Train Acc : 86.7188, Test Acc : 85.5200
# Epoch 101 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5338, Test Loss : 1.6024, Train Acc : 92.1875, Test Acc : 88.2700
# Iteration : 260 - Train Loss : 1.5348, Test Loss : 1.6086, Train Acc : 92.9688, Test Acc : 87.7700
# Iteration : 390 - Train Loss : 1.5410, Test Loss : 1.6057, Train Acc : 91.4062, Test Acc : 88.0100
# Epoch 121 Started...
# Iteration : 130 - Train Loss : 1.5132, Test Loss : 1.6033, Train Acc : 95.3125, Test Acc : 88.0900
# Iteration : 260 - Train Loss : 1.5352, Test Loss : 1.6040, Train Acc : 92.9688, Test Acc : 88.1500
# Iteration : 390 - Train Loss : 1.5170, Test Loss : 1.6011, Train Acc : 94.5312, Test Acc : 88.1900
# Epoch 141 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 130 - Train Loss : 1.5423, Test Loss : 1.5944, Train Acc : 91.4062, Test Acc : 89.4500
# Iteration : 260 - Train Loss : 1.5233, Test Loss : 1.6059, Train Acc : 94.5312, Test Acc : 87.7500
# Iteration : 390 - Train Loss : 1.5289, Test Loss : 1.6001, Train Acc : 94.5312, Test Acc : 88.1700
# Epoch 161 Started...
# Iteration : 130 - Train Loss : 1.5159, Test Loss : 1.5920, Train Acc : 95.3125, Test Acc : 89.2600
# Iteration : 260 - Train Loss : 1.5158, Test Loss : 1.5998, Train Acc : 94.5312, Test Acc : 88.3700
# Iteration : 390 - Train Loss : 1.4990, Test Loss : 1.5957, Train Acc : 96.0938, Test Acc : 88.8300
# Epoch 181 Started...
# Iteration : 130 - Train Loss : 1.5162, Test Loss : 1.5987, Train Acc : 95.3125, Test Acc : 88.5900
# Iteration : 260 - Train Loss : 1.5137, Test Loss : 1.5925, Train Acc : 95.3125, Test Acc : 89.1000
# Iteration : 390 - Train Loss : 1.5436, Test Loss : 1.5979, Train Acc : 92.1875, Test Acc : 88.7100
# Epoch 201 Started...
# Iteration : 130 - Train Loss : 1.5175, Test Loss : 1.5936, Train Acc : 94.5312, Test Acc : 89.1600
# Iteration : 260 - Train Loss : 1.4905, Test Loss : 1.5917, Train Acc : 97.6562, Test Acc : 89.1700
# Iteration : 390 - Train Loss : 1.5301, Test Loss : 1.5945, Train Acc : 92.1875, Test Acc : 88.8800
# Epoch 221 Started...
# Iteration : 130 - Train Loss : 1.4873, Test Loss : 1.5936, Train Acc : 97.6562, Test Acc : 89.4000
# Iteration : 260 - Train Loss : 1.5351, Test Loss : 1.5982, Train Acc : 92.9688, Test Acc : 88.5500
# Iteration : 390 - Train Loss : 1.4941, Test Loss : 1.5930, Train Acc : 97.6562, Test Acc : 89.4200
# Epoch 241 Started...
# Iteration : 130 - Train Loss : 1.5128, Test Loss : 1.5981, Train Acc : 94.5312, Test Acc : 88.7700
# Iteration : 260 - Train Loss : 1.4859, Test Loss : 1.5935, Train Acc : 98.4375, Test Acc : 89.0100
# Iteration : 390 - Train Loss : 1.5076, Test Loss : 1.6059, Train Acc : 95.3125, Test Acc : 87.8800
# Epoch 261 Started...
# Iteration : 130 - Train Loss : 1.5027, Test Loss : 1.5895, Train Acc : 96.0938, Test Acc : 89.2900
# Iteration : 260 - Train Loss : 1.4986, Test Loss : 1.5943, Train Acc : 96.8750, Test Acc : 89.0900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 390 - Train Loss : 1.4847, Test Loss : 1.5866, Train Acc : 98.4375, Test Acc : 89.7000

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(ZFNet.train_losses, label='Train')
test_lossline, = plt.plot(ZFNet.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(ZFNet.train_acc, label='Train')
test_accline, = plt.plot(ZFNet.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
